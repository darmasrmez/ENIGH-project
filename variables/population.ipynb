# %% [markdown]
# # Select variables for Population-ENIGH dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
population_df = pd.read_csv('../datasets-ENIGH/conjunto_de_datos_poblacion_enigh_2016_ns/conjunto_de_datos/conjunto_de_datos_poblacion_enigh_2016_ns.csv')
population_df.head()
# Out:
# C:\Users\magui\AppData\Local\Temp\ipykernel_7220\464118857.py:1: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   population_df = pd.read_csv('../datasets-ENIGH/conjunto_de_datos_poblacion_enigh_2016_ns/conjunto_de_datos/conjunto_de_datos_poblacion_enigh_2016_ns.csv')
#     folioviv  foliohog  numren  parentesco  sexo  edad  madre_hog madre_id  \
# 0  100068001         1       2         201     2    71          2      NaN
# 1  100068002         1       1         101     1    64          2      NaN
# 2  100068002         1       2         201     2    61          2      NaN
# 3  100068002         1       3         301     2    24          1        2
# 4  100068003         1       1         101     1    82          2      NaN
#
#    padre_hog padre_id  ... segvol_6  segvol_7  hijos_viv  hijos_mue  \
# 0          2      NaN  ...      6.0       NaN          9          2
# ...

# %%
population_df.shape
# Out:
# (257805, 178)

# %%
population_df.columns.values
# Out:
# array(['folioviv', 'foliohog', 'numren', 'parentesco', 'sexo', 'edad',
#        'madre_hog', 'madre_id', 'padre_hog', 'padre_id', 'disc1', 'disc2',
#        'disc3', 'disc4', 'disc5', 'disc6', 'disc7', 'causa1', 'causa2',
#        'causa3', 'causa4', 'causa5', 'causa6', 'causa7', 'hablaind',
#        'lenguaind', 'hablaesp', 'comprenind', 'etnia', 'alfabetism',
#        'asis_esc', 'nivel', 'grado', 'tipoesc', 'tiene_b', 'otorg_b',
#        'forma_b', 'tiene_c', 'otorg_c', 'forma_c', 'nivelaprob',
#        'gradoaprob', 'antec_esc', 'residencia', 'edo_conyug',
#        'pareja_hog', 'conyuge_id', 'segsoc', 'ss_aa', 'ss_mm', 'redsoc_1',
#        'redsoc_2', 'redsoc_3', 'redsoc_4', 'redsoc_5', 'redsoc_6',
#        'hor_1', 'min_1', 'usotiempo1', 'hor_2', 'min_2', 'usotiempo2',
#        'hor_3', 'min_3', 'usotiempo3', 'hor_4', 'min_4', 'usotiempo4',
#        'hor_5', 'min_5', 'usotiempo5', 'hor_6', 'min_6', 'usotiempo6',
# ...

# %% [markdown]
# ## Features selection
# 1. Domain knowledge selection

# %%
keys = ['folioviv', 'foliohog', 'numren']
relevant = ['edad', 'disc1', 'disc2', 'causa1', 'causa2', 'hablaind', 'alfabetism', 'nivel', 'tiene_c', 'forma_c',
            'nivelaprob', 'edo_conyug', 'pareja_hog', 'hor_1', 'usotiempo2', 'usotiempo6', 'hor_8', 'atemed', 'noatenc_2',
            'peso', 'segvol_3', 'hijos_viv', 'num_trabaj']

# %%
population_df = population_df[keys + relevant]
population_df.head()
# Out:
#     folioviv  foliohog  numren  edad disc1  disc2 causa1  causa2  hablaind  \
# 0  100068001         1       2    71     8    NaN    NaN     NaN       2.0
# 1  100068002         1       1    64     8    NaN    NaN     NaN       2.0
# 2  100068002         1       2    61     8    NaN    NaN     NaN       2.0
# 3  100068002         1       3    24     8    NaN    NaN     NaN       2.0
# 4  100068003         1       1    82     8    NaN    NaN     NaN       2.0
#
#    alfabetism  ...  hor_1  usotiempo2  usotiempo6  hor_8  atemed  noatenc_2  \
# 0         2.0  ...      0         9.0         NaN     42     1.0        NaN
# 1         1.0  ...     12         9.0         9.0      6     1.0        NaN
# 2         1.0  ...      0         9.0         NaN     34     1.0        NaN
# 3         1.0  ...     48         9.0         NaN     28     1.0        NaN
# 4         1.0  ...     20         9.0         NaN     40     1.0        NaN
#
#    peso  segvol_3  hijos_viv  num_trabaj
# ...
